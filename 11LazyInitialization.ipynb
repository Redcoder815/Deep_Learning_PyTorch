# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/Deep_Learning_PyTorch/blob/main/11LazyInitialization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn

# %%
net = nn.Sequential(nn.LazyLinear(256), nn.ReLU(), nn.LazyLinear(10))

# %%
net[0].weight

# %%
X = torch.rand(2, 20)
net(X)

net[0].weight.shape
net[2].weight.shape
# Out:
# torch.Size([10, 256])
